# %% [markdown]
# # Background Subtraction Algorithm for Cloud Masking

# %%
# !pip install Pillow
# !pip install rembg

# %%
import cv2
import torch
from google.colab import drive
from google.colab.patches import cv2_imshow as show
from rembg import remove
from torchvision import transforms
from matplotlib import pyplot as plt

from PIL import Image, ImageChops
import numpy as np
from IPython.display import display
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
background = Image.open('/content/drive/MyDrive/ENEE439D Group Project/Cloud Data Pre-Background Subtraction/backgroundNEW1.jpg')

# INSERT YOUR IMAGE HERE
overlay = Image.open('/content/drive/MyDrive/ENEE439D Group Project/Cloud Data Pre-Background Subtraction/newOne.jpg')
diff = ImageChops.difference(background, overlay)
if diff.getbbox():
    diff.show()
left = 40
top = 50
right = diff.width - 34
bottom = diff.height - 24
# Crop image
cropped_image = diff.crop((left, top, right, bottom))
display(cropped_image)
#difference_path = '/mnt/data/difference_image.png'
#difference_image.save(difference_path)

#difference_path
# Out:
# <PIL.Image.Image image mode=RGB size=1846x1006>
